# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,classification_report
import matplotlib.pyplot as plt 
from  sklearn import tree 
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv(r"C:\\Users\\uday2\\Desktop\\python\\DATASET\\new data sets\\heart.csv")

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.shape
data['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
#x = data.drop('target','sex', axis=1)
x = data.drop(['target', 'sex','fbs'], axis=1)
# This is my target column (0,1)
y = data['target']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=141)
x_train1,x_test1,y_train1,y_test1=train_test_split(x,y,test_size=0.1,random_state=141)

# %%
dt_model=DecisionTreeClassifier(max_depth=5,random_state=42,criterion='entropy',min_samples_split=23)

# %%
x.head()
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: target, dtype: int64

# %%
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=23,
#                        random_state=42)

# %%
y_pred=dt_model.predict(x_test)

# %%
accuracy=(accuracy_score(y_test,y_pred))*100
accuracy
# Out:
# 96.7741935483871

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[12,  1],
#        [ 0, 18]], dtype=int64)

# %%
print((12+18)/(0+12+1+18)*100)
print((12)/(0+12)*100)#recall
print(12/(12+1)*100)#precision
# Out:
# 96.7741935483871
# 100.0
# 92.3076923076923

# %%
rf_model = RandomForestClassifier(n_estimators=120, criterion="entropy", random_state=150)

# %%
rf_model.fit(x_train1,y_train1)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=120, random_state=150)

# %%
y_pred1=rf_model.predict(x_test1)

# %%
accuracy1 =(accuracy_score(y_test1,y_pred2)*100)
accuracy1
# Out:
# 96.7741935483871

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test1,y_pred2)
# Out:
# array([[12,  1],
#        [ 0, 18]], dtype=int64)

# %%
print((12+18)/(12+0+1+18)*100)
print((12)/(0+12)*100)#recall
print(12/(12+1)*100)#precision
# Out:
# 96.7741935483871
# 100.0
# 92.3076923076923

# %%
#x = data.drop('target','sex', axis=1)
X = data.drop(['target', 'sex','fbs'], axis=1)
# This is my target column (0,1)
Y = data['target']

# %%
#X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=2)
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=4)#predic accuracy=93.54,recall=100,precision=84.61

# %%
from sklearn.linear_model import LogisticRegression

# %%
#lgmodel=LogisticRegression(max_iter=900) #(best paramter for ideal recall and precision)
lgmodel=LogisticRegression(max_iter=1000)

# %%
lgmodel.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
Y_pred=lgmodel.predict(X_test)

# %%
accurcy3=(accuracy_score(Y_test,Y_pred)*100)
accurcy3
# Out:
# 93.54838709677419

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,Y_pred)
#ideal i got so far array([[21,  4],
       #[ 1, 35]], dtype=int64)

print(classification_report(Y_test,Y_pred))
confusion_matrix(Y_test,Y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92        13
#            1       0.90      1.00      0.95        18
#
#     accuracy                           0.94        31
#    macro avg       0.95      0.92      0.93        31
# weighted avg       0.94      0.94      0.93        31
# array([[11,  2],
#        [ 0, 18]], dtype=int64)

# %%
#accuracy
#print(((21+35)/(22+4+1+35))*100)
#print(((13+15)/(13+1+2+15))*100)
print(((11+18)/(11+0+2+18))*100)#recall of the 100
# Out:
# 93.54838709677419

# %%
#recall and #percision are used whenr 
#print((13)/(13+1)*100)
print((11)/(11+0)*100)#most ideal for my target with low recall
# Out:
# 100.0

# %%
#precision
print((11)/(11+2)*100)
# Out:
# 84.61538461538461

# %%
from sklearn.svm import SVC

# %%
a = data.drop(['target', 'sex','fbs'], axis=1)
b = data['target']
a_train, a_test, b_train, b_test = train_test_split(a, b, test_size=0.1, random_state=4)

# %%
svc_model = SVC(kernel='linear',degree=7, gamma='scale', coef0=0.0, shrinking=False, random_state=42, C=5) 
svc_model.fit(a_train,b_train)
# Out:
# SVC(C=5, degree=7, kernel='linear', random_state=42, shrinking=False)

# %%
b_pred=svc_model.predict(a_test)

# %%
accuracy=(accuracy_score(b_test,b_pred)*100)

# %%
accuracy
# Out:
# 90.32258064516128

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(b_pred,b_test)
# Out:
# array([[11,  1],
#        [ 2, 17]], dtype=int64)

# %%
print(classification_report(b_test,b_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88        13
#            1       0.89      0.94      0.92        18
#
#     accuracy                           0.90        31
#    macro avg       0.91      0.90      0.90        31
# weighted avg       0.90      0.90      0.90        31

# %%
#accuracy
print(((13+16)/(13+0+2+16))*100)
# Out:
# 93.54838709677419

# %%
#recall
print(11/(11+2)*100)
# Out:
# 84.61538461538461

# %%
#precision
print(13/(13+0)*100)
# Out:
# 100.0

# %%
a1 = data.drop(['target', 'sex','fbs'], axis=1)
b1 = data['target']
#a1_train, a1_test, b1_train, b1_test = train_test_split(a1, b1, test_size=0.1, random_state=35)
#a1_train, a1_test, b1_train, b1_test = train_test_split(a1, b1, test_size=0.1, random_state=39)#recall,precision,acuracy =80%
#a1_train, a1_test, b1_train, b1_test = train_test_split(a1, b1, test_size=0.1, random_state=41)#recall&prec=84 and acc=87
a1_train, a1_test, b1_train, b1_test = train_test_split(a1, b1, test_size=0.1, random_state=45)

# %%
svc_model1 = SVC(kernel="linear", C=1) 
svc_model1.fit(a1_train,b1_train)
# Out:
# SVC(C=1, kernel='linear')

# %%
b_pred1=svc_model1.predict(a1_test)

# %%
accur=(accuracy_score(b1_test,b_pred1)*100)
accur
# Out:
# 77.41935483870968

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(b_pred1,b1_test))
# Out:
# [[ 5  3]
#  [ 4 19]]

# %%
#recall
print((8/(8+1))*100)
# Out:
# 88.88888888888889

# %%
#precision
print((8/(8+1))*100)
# Out:
# 88.88888888888889

# %%
print(classification_report(b_pred1,b1_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89         9
#            1       0.95      0.95      0.95        22
#
#     accuracy                           0.94        31
#    macro avg       0.92      0.92      0.92        31
# weighted avg       0.94      0.94      0.94        31
